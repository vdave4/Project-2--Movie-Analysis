# %%
# import libraries
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)  #  adjusts the configuration of the plots we will create

pd.options.mode.chained_assignment = None

# reading the data
df = pd.read_csv("C:\\Users\\alive\\movies.csv\\movies.csv")

# %%
# lookig at the data

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# check to see if we have any missing data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print("{} - {}%".format(col, pct_missing))

#dropping the null values

df = df.dropna()
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
# data types of columns

df.dtypes

# change the data type
df["budget"] = df["budget"].astype("int64")

df["gross"] = df["gross"].astype("int64")

df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
#released date as same as year- create correct year column

df["yearcorect"] = df["released"].str.extract(pat = "([0-9]{4})").astype("int64")

df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
# sorting gross column n descending order

df.sort_values(by = ["gross"], inplace = False, ascending = False)

pd.set_option("display.max_rows", None)

# %%
# remove any duplicates

df["company"].drop_duplicates().sort_values(ascending = False)
# Out:
# 7129    1474
# 5664    1473
# 4007    1472
# 6793    1471
# 6420    1470
# 3776    1469
# 3330    1468
# 146     1467
# 2213    1466
# 3698    1465
# 1180    1464
# 5180    1463
# 1321    1462
# 1329    1461
# 789     1460
# 5125    1459
# 5499    1458
# 4618    1457
# 4990    1456
# 5410    1455
# 5583    1454
# 6265    1453
# 4392    1452
# 4999    1451
# 425     1450
# 4581    1449
# 4272    1448
# 450     1447
# 3943    1446
# 2084    1445
# 2355    1444
# 6606    1443
# 5276    1442
# 4863    1441
# 5550    1440
# 4572    1439
# 6616    1438
# 1306    1437
# 1475    1436
# 1744    1435
# 1304    1434
# 5496    1433
# 6672    1432
# 4505    1431
# 7267    1430
# 2284    1429
# 6578    1428
# 2341    1427
# 0       1426
# 7401    1425
# 75      1424
# 688     1423
# 117     1422
# 5075    1421
# 4975    1420
# 7420    1419
# 5272    1418
# 5409    1417
# 1115    1416
# 6647    1415
# 1307    1414
# 3539    1413
# 2467    1412
# 1894    1411
# 1716    1410
# 4964    1409
# ...

# %%
df.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  4692       6      6  1980      1304    8.4   927000.0      1795    2832
# 1  3929       6      1  1980      1127    5.8    65000.0      1578    1158
# 2  3641       4      0  1980      1359    8.7  1200000.0       757    1818
# 3   204       4      4  1980      1127    7.7   221000.0       889    1413
# 4   732       6      4  1980      1170    7.3   108000.0       719     351
#
#    star  country    budget      gross  company  runtime  yearcorect
# 0   699       46  19000000   46998772     1426    146.0        1980
# 1   214       47   4500000   58853106      452    104.0        1980
# 2  1157       47  18000000  538375067      945    124.0        1980
# 3  1474       47   3500000   83453539     1108     88.0        1980
# 4   271       47   6000000   39846344     1083     98.0        1980

# %%
#  Predictions:
# 1. Higher Budget will yield high gross income
# 2. Better the company, higher the gross income

# %%
# Scatter plot of Budget v/s gross revenue

plt.scatter(x = df["budget"], y = df["gross"])
plt.title("Budget v/s Gross Earnings")
plt.xlabel("Gross Earnings")
plt.ylabel("Budget for Film")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Plot Budget vs Gross using Seaborn

sns.regplot(x = "budget", y = "gross", data = df, scatter_kws = {"color": "red"}, line_kws = {"color": "blue"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
# Correlation 

df.corr()
# Out:
#                 year     score     votes    budget     gross   runtime  \
# year        1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score       0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes       0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget      0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross       0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime     0.075077  0.414068  0.352303  0.318695  0.275796  1.000000
# yearcorect  0.998726  0.061923  0.203098  0.320312  0.268721  0.075294
#
#             yearcorect
# year          0.998726
# score         0.061923
# votes         0.203098
# budget        0.320312
# gross         0.268721
# runtime       0.075294
# yearcorect    1.000000

# %%
# High Correlation between Gross and Budget

# My prediction is correct as it shows in the graph a high correlation between gross and budget

# %%
correlation_matrix = df.corr()

sns.heatmap(correlation_matrix, annot = True)
plt.title("Correlation Matrix for Numeric Features")
plt.xlabel("Movie Features")
plt.ylabel("Movie Features")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# lokking at the company correlation
# changing the string values to numerical codes to find the correlation

df.numerized = df

for col_names in df.numerized.columns:
    if (df.numerized[col_names].dtype == "object"):
        df.numerized[col_names] = df.numerized[col_names].astype("category")
        df.numerized[col_names] = df.numerized[col_names].cat.codes
        
df.numerized.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  4692       6      6  1980      1304    8.4   927000.0      1795    2832
# 1  3929       6      1  1980      1127    5.8    65000.0      1578    1158
# 2  3641       4      0  1980      1359    8.7  1200000.0       757    1818
# 3   204       4      4  1980      1127    7.7   221000.0       889    1413
# 4   732       6      4  1980      1170    7.3   108000.0       719     351
#
#    star  country    budget      gross  company  runtime  yearcorect
# 0   699       46  19000000   46998772     1426    146.0        1980
# 1   214       47   4500000   58853106      452    104.0        1980
# 2  1157       47  18000000  538375067      945    124.0        1980
# 3  1474       47   3500000   83453539     1108     88.0        1980
# 4   271       47   6000000   39846344     1083     98.0        1980

# %%
#plotting the correlation

correlation_matrix = df.numerized.corr()

sns.heatmap(correlation_matrix, annot = True)
plt.title("Correlation Matrix for Numeric Features")
plt.xlabel("Movie Features")
plt.ylabel("Movie Features")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# table of correlation
df.numerized.corr()
# Out:
#                 name    rating     genre      year  released     score  \
# name        1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# rating     -0.029234  1.000000  0.147796  0.019499  0.018083  0.065983
# genre       0.010996  0.147796  1.000000 -0.073167  0.022142  0.035106
# year        0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
# released   -0.006152  0.018083  0.022142 -0.001740  1.000000  0.045874
# score       0.014450  0.065983  0.035106  0.056386  0.045874  1.000000
# votes       0.012615  0.006031 -0.135990  0.206021  0.028833  0.474256
# director    0.015246  0.014656 -0.008553 -0.038354  0.002308  0.005413
# writer      0.012880 -0.003149  0.017578 -0.025908  0.008072  0.012843
# star       -0.006882  0.009196  0.003341 -0.032157  0.015706  0.007296
# country    -0.025490  0.008230 -0.009164 -0.066748 -0.017228 -0.043051
# budget      0.023392 -0.203946 -0.368523  0.327722  0.019952  0.072001
# ...

# %%
# unstacking to find the correlation 

correlation_mat = df.numerized.corr()

corr_pair = correlation_mat.unstack()
corr_pair.head()
# Out:
# name  name        1.000000
#       rating     -0.029234
#       genre       0.010996
#       year        0.025542
#       released   -0.006152
# dtype: float64

# %%
# sorting the pairs
sorted_pairs = corr_pair.sort_values()
sorted_pairs.head()
# Out:
# genre   budget   -0.368523
# budget  genre    -0.368523
# gross   genre    -0.244101
# genre   gross    -0.244101
# rating  budget   -0.203946
# dtype: float64

# %%
# High correlation

high_corr = sorted_pairs[(sorted_pairs) > 0.5]
high_corr
# Out:
# gross       votes         0.614751
# votes       gross         0.614751
# gross       budget        0.740247
# budget      gross         0.740247
# year        yearcorect    0.998726
# yearcorect  year          0.998726
# name        name          1.000000
# company     company       1.000000
# gross       gross         1.000000
# budget      budget        1.000000
# country     country       1.000000
# star        star          1.000000
# writer      writer        1.000000
# director    director      1.000000
# votes       votes         1.000000
# score       score         1.000000
# released    released      1.000000
# year        year          1.000000
# genre       genre         1.000000
# rating      rating        1.000000
# runtime     runtime       1.000000
# yearcorect  yearcorect    1.000000
# dtype: float64

# %%
# Conclusion

# Votes and Budget has he highest correlation to Gross Earnings.
# My second prediction is incorrect as the correlation between is Company and Gross Earnings is not high.
